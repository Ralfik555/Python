# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#ploting 

import matplotlib as mlp
import matplotlib.pyplot as plt

# %%
#stats
from scipy import stats

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 4., 12., 11., 15., 17., 11., 14.,  9.,  3.,  4.]),
#  array([-1.6239937 , -1.24024986, -0.85650602, -0.47276218, -0.08901834,
#          0.29472549,  0.67846933,  1.06221317,  1.44595701,  1.82970085,
#          2.21344469]),
#  <a list of 10 Patch objects>)

# %%
dataset2 =randn(80)
plt.hist(dataset1, bins= 6,color = 'red')
# Out:
# (array([13., 18., 28., 22., 12.,  7.]),
#  array([-1.6239937 , -0.98442064, -0.34484757,  0.29472549,  0.93429856,
#          1.57387162,  2.21344469]),
#  <a list of 6 Patch objects>)

# %%
plt.hist(dataset1,density=True,bins = 40,color='indianred',alpha = 0.5)
plt.hist(dataset2,density=True,bins = 40,color='blue',alpha = 0.7)
# Out:
# (array([0.11195472, 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.11195472, 0.33586417, 0.11195472, 0.22390945,
#         0.55977362, 0.33586417, 0.33586417, 0.22390945, 0.33586417,
#         0.4478189 , 0.11195472, 0.22390945, 0.11195472, 0.4478189 ,
#         0.33586417, 0.22390945, 0.78368307, 0.55977362, 0.4478189 ,
#         1.00759252, 0.33586417, 0.33586417, 0.33586417, 0.11195472,
#         0.11195472, 0.11195472, 0.        , 0.        , 0.        ,
#         0.        , 0.11195472, 0.        , 0.        , 0.11195472]),
#  array([-2.41163146, -2.29997918, -2.1883269 , -2.07667462, -1.96502234,
#         -1.85337006, -1.74171779, -1.63006551, -1.51841323, -1.40676095,
#         -1.29510867, -1.18345639, -1.07180412, -0.96015184, -0.84849956,
#         -0.73684728, -0.625195  , -0.51354272, -0.40189045, -0.29023817,
#         -0.17858589, -0.06693361,  0.04471867,  0.15637094,  0.26802322,
#          0.3796755 ,  0.49132778,  0.60298006,  0.71463234,  0.82628461,
#          0.93793689,  1.04958917,  1.16124145,  1.27289373,  1.38454601,
#          1.49619828,  1.60785056,  1.71950284,  1.83115512,  1.9428074 ,
#          2.05445968]),
#  <a list of 40 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind = 'hex')

# %%
#Kernel Density Estimation plot

# %%
dataset = randn(25)

# %%
sns.rugplot(dataset)
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
plt.hist(dataset,alpha = 0.3)
sns.rugplot(dataset)

# %%
sns.rugplot(dataset)
x_min,x_max = dataset.min() - 2, dataset.max() + 2
x_axis = np.linspace(x_min,x_max,num=100)
band_width = ((4*(dataset.std())**5)/(3*len(dataset)))**0.2
kernel_list = []

for datapoint in dataset:
    kernel = stats.norm(datapoint,band_width).pdf(x_axis)
    kernel_list.append(kernel)
    
    kernel = kernel / kernel.max()
    kernel = kernel * 0.4
    
    plt.plot(x_axis,kernel,alpha = 0.5,color='grey')
    

plt.ylim(0,1)
sum_kernel_list = sum(kernel_list)

# %%
fig = plt.plot(x_axis,sum_kernel_list,color= 'indianred')
sns.rugplot(dataset)
plt.yticks([])
plt.suptitle('Sum of basic functions')
# Out:
# Text(0.5, 0.98, 'Sum of basic functions')

# %%
sns.kdeplot(dataset)

# %%
sns.rugplot(dataset,color='black')

# Plot various bandwidths
for bw in np.arange(0.5,2,0.25):
    sns.kdeplot(dataset,bw=bw,lw=1.8,label=bw)

# %%
sns.kdeplot(dataset,bw=1,lw=1.8,label=bw)

# %%
kernel_options = ["biw", "cos", "epa", "gau", "tri", "triw"]

# %%
for ko in kernel_options:
    sns.kdeplot(dataset,kernel=ko ,label = ko,shade = True)

# %%
sns.kdeplot(dataset,vertical=True)

# %%
sns.kdeplot(dataset,cumulative=True)

# %%
# Mean center of data
mean = [0,0]

# Diagonal covariance
cov = [[1,0],[0,100]]

# Create dataset using numpy
dataset2 = np.random.multivariate_normal(mean,cov,1000)

# Bring back our old friend pandas
dframe = pd.DataFrame(dataset2,columns=['X','Y'])

# %%
sns.kdeplot(dframe)

# %%
sns.kdeplot(dframe.X,dframe.Y,shade = True)

# %%
sns.kdeplot(dframe,bw=.8)

# %%
sns.kdeplot(dframe,bw = 'silverman')

# %%
sns.jointplot('X','Y',dframe,kind='kde')
